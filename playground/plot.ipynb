# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
input_data = pd.read_csv("../export/input.csv")
activity = pd.read_csv("../export/neural_activity.csv")

x = input_data["0"]
y = [activity["0"],activity["1"],activity["2"],activity["3"],activity["4"],activity["5"]]

# %%
plt.plot(input_data["0"])

# %%
plt.figure()
plt.plot(activity["0"])
plt.figure()
plt.plot(activity["1"])
plt.figure()
plt.plot(activity["2"])
plt.figure()
plt.plot(activity["3"])
plt.figure()
plt.plot(activity["4"])
plt.figure()
plt.plot(activity["5"])

# %%
data = pd.read_csv("../export/network/2021-10-24-19:33:40_2000_784_mnist_network/Output Layer.csv")
plt.imshow(data.to_numpy().T)
plt.savefig("output.png")

# %%
from keras.datasets import mnist
(train_X, train_y), (test_X, test_y) = mnist.load_data()
# Out:
# Error: Session cannot generate requests
# at w.executeCodeCell (/Users/takashimac/.vscode/extensions/ms-toolsai.jupyter-2021.6.999662501/out/client/extension.js:90:328422)
# at w.execute (/Users/takashimac/.vscode/extensions/ms-toolsai.jupyter-2021.6.999662501/out/client/extension.js:90:327811)
# at w.start (/Users/takashimac/.vscode/extensions/ms-toolsai.jupyter-2021.6.999662501/out/client/extension.js:90:323627)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at async t.CellExecutionQueue.executeQueuedCells (/Users/takashimac/.vscode/extensions/ms-toolsai.jupyter-2021.6.999662501/out/client/extension.js:90:338053)
# at async t.CellExecutionQueue.start (/Users/takashimac/.vscode/extensions/ms-toolsai.jupyter-2021.6.999662501/out/client/extension.js:90:337593)

# %%
plt.imshow(one_img)
# Out:
# Error: Session cannot generate requests
# at w.executeCodeCell (/Users/takashimac/.vscode/extensions/ms-toolsai.jupyter-2021.6.999662501/out/client/extension.js:90:328422)
# at w.execute (/Users/takashimac/.vscode/extensions/ms-toolsai.jupyter-2021.6.999662501/out/client/extension.js:90:327811)
# at w.start (/Users/takashimac/.vscode/extensions/ms-toolsai.jupyter-2021.6.999662501/out/client/extension.js:90:323627)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at async t.CellExecutionQueue.executeQueuedCells (/Users/takashimac/.vscode/extensions/ms-toolsai.jupyter-2021.6.999662501/out/client/extension.js:90:338053)
# at async t.CellExecutionQueue.start (/Users/takashimac/.vscode/extensions/ms-toolsai.jupyter-2021.6.999662501/out/client/extension.js:90:337593)
